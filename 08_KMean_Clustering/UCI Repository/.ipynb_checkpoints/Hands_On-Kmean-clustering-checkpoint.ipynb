# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('Online Retail.csv', delimiter = ',' , encoding = "ISO-8859-1")

# %%
data.head(10)
# Out:
#   ï»¿InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5       536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6       536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7       536366     22633               HAND WARMER UNION JACK         6
# 8       536366     22632            HAND WARMER RED POLKA DOT         6
# 9       536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 5  01-12-2010 08:26       7.65     17850.0  United Kingdom
# 6  01-12-2010 08:26       4.25     17850.0  United Kingdom
# 7  01-12-2010 08:28       1.85     17850.0  United Kingdom
# 8  01-12-2010 08:28       1.85     17850.0  United Kingdom
# 9  01-12-2010 08:34       1.69     13047.0  United Kingdom

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ï»¿InvoiceNo  541909 non-null  object
#  1   StockCode     541909 non-null  object
#  2   Description   540455 non-null  object
#  3   Quantity      541909 non-null  int64
#  4   InvoiceDate   541909 non-null  object
#  5   UnitPrice     541909 non-null  float64
#  6   CustomerID    406829 non-null  float64
#  7   Country       541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data.info
# Out:
# <bound method DataFrame.info of        ï»¿InvoiceNo StockCode                          Description  Quantity  \
# 0            536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1            536365     71053                  WHITE METAL LANTERN         6
# 2            536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3            536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4            536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...             ...       ...                                  ...       ...
# 541904       581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905       581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906       581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907       581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908       581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 0       01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1       01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2       01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3       01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4       01-12-2010 08:26       3.39     17850.0  United Kingdom
# ...                  ...        ...         ...             ...
# 541904  09-12-2011 12:50       0.85     12680.0          France
# 541905  09-12-2011 12:50       2.10     12680.0          France
# 541906  09-12-2011 12:50       4.15     12680.0          France
# 541907  09-12-2011 12:50       4.15     12680.0          France
# 541908  09-12-2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]>

# %%
data.describe().T # using .T we have done transpose
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %%
data.describe(exclude = ['int64', 'float64']).T
# Out:
#                count unique                                 top    freq
# ï»¿InvoiceNo  541909  25900                              573585    1114
# StockCode     541909   4070                              85123A    2313
# Description   540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# InvoiceDate   541909  23260                    31-10-2011 14:41    1114
# Country       541909     38                      United Kingdom  495478

# %%
data.isnull().sum()
# Out:
# ï»¿InvoiceNo         0
# StockCode            0
# Description       1454
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID      135080
# Country              0
# dtype: int64

# %% [markdown]
# ### Delete all the missing records

# %%
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (406829, 8)

# %%
541909 - 406829 # How many null values we have removed.
# Out:
# 135080

# %%
data[data['Quantity']<0]
# Out:
#        ï»¿InvoiceNo StockCode                       Description  Quantity  \
# 141         C536379         D                          Discount        -1
# 154         C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235         C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236         C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237         C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...             ...       ...                               ...       ...
# 540449      C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541      C581499         M                            Manual        -1
# 541715      C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716      C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717      C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 141     01-12-2010 09:41      27.50     14527.0  United Kingdom
# 154     01-12-2010 09:49       4.65     15311.0  United Kingdom
# 235     01-12-2010 10:24       1.65     17548.0  United Kingdom
# 236     01-12-2010 10:24       0.29     17548.0  United Kingdom
# 237     01-12-2010 10:24       0.29     17548.0  United Kingdom
# ...                  ...        ...         ...             ...
# 540449  09-12-2011 09:57       0.83     14397.0  United Kingdom
# 541541  09-12-2011 10:28     224.69     15498.0  United Kingdom
# 541715  09-12-2011 11:57      10.95     15311.0  United Kingdom
# 541716  09-12-2011 11:58       1.25     17315.0  United Kingdom
# 541717  09-12-2011 11:58       1.25     17315.0  United Kingdom
#
# [8905 rows x 8 columns]

# %%
data[data['UnitPrice']<0].shape[0]
# Out:
# 0

# %%
data.drop(data[data['Quantity']<0].index, inplace = True)

# %%
data.shape
# Out:
# (397924, 8)

# %% [markdown]
# ### Calculation of total amount or monetary value

# %%
data['Sales'] = data['Quantity']* data['UnitPrice']
new_data = data.groupby('CustomerID')['Sales'].sum().reset_index()
new_data
# Out:
#       CustomerID     Sales
# 0        12346.0  77183.60
# 1        12347.0   4310.00
# 2        12348.0   1797.24
# 3        12349.0   1757.55
# 4        12350.0    334.40
# ...          ...       ...
# 4334     18280.0    180.60
# 4335     18281.0     80.82
# 4336     18282.0    178.05
# 4337     18283.0   2094.88
# 4338     18287.0   1837.28
#
# [4339 rows x 2 columns]

# %% [raw]
# This will show the spending power of each customer have.

# %%
type(new_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###

# %% [markdown]
# ### Calculating the number of transactions of each customer

# %%
num_trans = data.groupby('CustomerID')['ï»¿InvoiceNo'].count().reset_index()

# %%
num_trans
# Out:
#       CustomerID  ï»¿InvoiceNo
# 0        12346.0             1
# 1        12347.0           182
# 2        12348.0            31
# 3        12349.0            73
# 4        12350.0            17
# ...          ...           ...
# 4334     18280.0            10
# 4335     18281.0             7
# 4336     18282.0            12
# 4337     18283.0           756
# 4338     18287.0            70
#
# [4339 rows x 2 columns]

# %%
type(num_trans)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Calculate Last Transaction

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'], dayfirst=True)

# %%
data['Last Transaction'] = (data['InvoiceDate'].max() - data['InvoiceDate']).dt.days

# %%
data.head(10)
# Out:
#   ï»¿InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5       536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6       536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7       536366     22633               HAND WARMER UNION JACK         6
# 8       536366     22632            HAND WARMER RED POLKA DOT         6
# 9       536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Sales  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom  15.30
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom  25.50
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom  11.10
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom  11.10
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom  54.08
#
#    Last Transaction
# 0               373
# 1               373
# 2               373
# 3               373
# 4               373
# 5               373
# 6               373
# 7               373
# 8               373
# 9               373

# %%
lt = data.groupby(['CustomerID', 'Country'])['Last Transaction'].max().reset_index()

# %%
merge_table = pd.merge(lt, num_trans,how = 'inner', on = 'CustomerID')
new_df = pd.merge(merge_table, new_data, how = 'inner', on = 'CustomerID')
new_df
# Out:
#       CustomerID         Country  Last Transaction  ï»¿InvoiceNo     Sales
# 0        12346.0  United Kingdom               325             1  77183.60
# 1        12347.0         Iceland               366           182   4310.00
# 2        12348.0         Finland               357            31   1797.24
# 3        12349.0           Italy                18            73   1757.55
# 4        12350.0          Norway               309            17    334.40
# ...          ...             ...               ...           ...       ...
# 4342     18280.0  United Kingdom               277            10    180.60
# 4343     18281.0  United Kingdom               180             7     80.82
# 4344     18282.0  United Kingdom               125            12    178.05
# 4345     18283.0  United Kingdom               336           756   2094.88
# 4346     18287.0  United Kingdom               201            70   1837.28
#
# [4347 rows x 5 columns]

# %% [markdown]
# ### Removing Outliers using boxplot

# %%
plt.figure(figsize=(20,20))
sns.boxplot(data = new_df[['ï»¿InvoiceNo', 'Last Transaction', 'Sales']])
plt.show()

# %%
IQR = new_df['Sales'].quantile(0.75) - new_df['Sales'].quantile(0.25)
lower_limit = new_df['Sales'].quantile(0.25) - 1.5*IQR
upper_limit = new_df['Sales'].quantile(0.75) + 1.5*IQR
new_df_iqr = new_df[(new_df['Sales']< upper_limit) & (new_df['Sales']>lower_limit)]
new_df_iqr.shape
# Out:
# (3923, 5)

# %%
plt.figure(figsize=(20,20))
sns.boxplot(data = new_df_iqr[['ï»¿InvoiceNo', 'Last Transaction', 'Sales']])
plt.show()

# %%
new_df_iqr.reset_index(drop = True, inplace = True)
new_df_iqr
# Out:
#       CustomerID         Country  Last Transaction  ï»¿InvoiceNo    Sales
# 0        12348.0         Finland               357            31  1797.24
# 1        12349.0           Italy                18            73  1757.55
# 2        12350.0          Norway               309            17   334.40
# 3        12352.0          Norway               296            85  2506.04
# 4        12353.0         Bahrain               203             4    89.00
# ...          ...             ...               ...           ...      ...
# 3918     18280.0  United Kingdom               277            10   180.60
# 3919     18281.0  United Kingdom               180             7    80.82
# 3920     18282.0  United Kingdom               125            12   178.05
# 3921     18283.0  United Kingdom               336           756  2094.88
# 3922     18287.0  United Kingdom               201            70  1837.28
#
# [3923 rows x 5 columns]

# %% [markdown]
# ### Visualiztion of correlation matix using heatmap

# %%
plt.figure(figsize=(20,20))
sns.heatmap(new_df_iqr.corr(),cmap='Greens', annot =True )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 plt.figure(figsize=(20,20))
# ----> 2 sns.heatmap(new_df_iqr.corr(),cmap='Greens', annot =True )
#       3 plt.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11045         """  # noqa: E501
#   11046         data = self._get_numeric_data() if numeric_only else self
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#   11052             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1989                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    1990         """
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#    1996
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Finland'

# %% [markdown]
# ### Normalization of given dataset using MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
new2_df = new_df_iqr[['Last Transaction', 'ï»¿InvoiceNo', 'Sales'  ]]
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(new2_df)
scaled_df = pd.DataFrame(scaled_df)
scaled_df.columns = ['Last Transaction','ï»¿InvoiceNo', 'Sales' ]
scaled_df['Country'] = new_df_iqr['Country']
scaled_df
# Out:
#       Last Transaction  ï»¿InvoiceNo     Sales         Country
# 0             0.957105      0.030960  0.484200         Finland
# 1             0.048257      0.074303  0.473507           Italy
# 2             0.828418      0.016512  0.090092          Norway
# 3             0.793566      0.086687  0.675160          Norway
# 4             0.544236      0.003096  0.023978         Bahrain
# ...                ...           ...       ...             ...
# 3918          0.742627      0.009288  0.048656  United Kingdom
# 3919          0.482574      0.006192  0.021774  United Kingdom
# 3920          0.335121      0.011352  0.047969  United Kingdom
# 3921          0.900804      0.779154  0.564388  United Kingdom
# 3922          0.538874      0.071207  0.494988  United Kingdom
#
# [3923 rows x 4 columns]

# %% [markdown]
# ### K Means Clusting - Plot the graph using elbow method

# %%
df_k = scaled_df.drop(columns= ['Country'], axis = 1)
#Elbow method for K Mean
# Import ElbowVisualizer

# %%
#Elbow method for K Mean
# Import ElbowVisualizer
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
# K is range of number of clusters
visualizer = KElbowVisualizer(model, k=(1,11), timings = False)
visualizer.fit(df_k) #fit data to visualizer
visualizer.show()
# Out:
# ---------------------------------------------------------------------------
# YellowbrickTypeError                      Traceback (most recent call last)
# Cell In[41], line 9
#       5 from yellowbrick.cluster import KElbowVisualizer
#       6
#       7 model = KMeans()
#       8 # K is range of number of clusters
# ----> 9 visualizer = KElbowVisualizer(model, k=(1,11), timings = False)
#      10 visualizer.fit(df_k) #fit data to visualizer
#      11 visualizer.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\yellowbrick\cluster\elbow.py:267, in KElbowVisualizer.__init__(self, estimator, ax, k, metric, distance_metric, timings, locate_elbow, **kwargs)
#     256 def __init__(
#     257     self,
#     258     estimator,
#    (...)    265     **kwargs
#     266 ):
# --> 267     super(KElbowVisualizer, self).__init__(estimator, ax=ax, **kwargs)
#     269     # Get the scoring method
#     270     if metric not in KELBOW_SCOREMAP:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\yellowbrick\cluster\base.py:45, in ClusteringScoreVisualizer.__init__(self, estimator, ax, fig, force_model, **kwargs)
#      43 def __init__(self, estimator, ax=None, fig=None, force_model=False, **kwargs):
#      44     if not force_model and not isclusterer(estimator):
# ---> 45         raise YellowbrickTypeError(
#      46             "The supplied model is not a clustering estimator; try a "
#      47             "classifier or regression score visualizer instead!"
#      48         )
#      49     self.force_model = force_model
#      50     super(ClusteringScoreVisualizer, self).__init__(
#      51         estimator, ax=ax, fig=fig, **kwargs
#      52     )
#
# YellowbrickTypeError: The supplied model is not a clustering estimator; try a classifier or regression score visualizer instead!

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# Initialize the model and visualizer
model = KMeans(random_state=42)
visualizer = KElbowVisualizer(model, k=(1, 11), timings=False)

# Fit and render the elbow plot
visualizer.fit(df_k)
visualizer.show()
# Out:
# ---------------------------------------------------------------------------
# YellowbrickTypeError                      Traceback (most recent call last)
# Cell In[45], line 6
#       2 from yellowbrick.cluster import KElbowVisualizer
#       3
#       4 # Initialize the model and visualizer
#       5 model = KMeans(random_state=42)
# ----> 6 visualizer = KElbowVisualizer(model, k=(1, 11), timings=False)
#       7
#       8 # Fit and render the elbow plot
#       9 visualizer.fit(df_k)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\yellowbrick\cluster\elbow.py:267, in KElbowVisualizer.__init__(self, estimator, ax, k, metric, distance_metric, timings, locate_elbow, **kwargs)
#     256 def __init__(
#     257     self,
#     258     estimator,
#    (...)    265     **kwargs
#     266 ):
# --> 267     super(KElbowVisualizer, self).__init__(estimator, ax=ax, **kwargs)
#     269     # Get the scoring method
#     270     if metric not in KELBOW_SCOREMAP:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\yellowbrick\cluster\base.py:45, in ClusteringScoreVisualizer.__init__(self, estimator, ax, fig, force_model, **kwargs)
#      43 def __init__(self, estimator, ax=None, fig=None, force_model=False, **kwargs):
#      44     if not force_model and not isclusterer(estimator):
# ---> 45         raise YellowbrickTypeError(
#      46             "The supplied model is not a clustering estimator; try a "
#      47             "classifier or regression score visualizer instead!"
#      48         )
#      49     self.force_model = force_model
#      50     super(ClusteringScoreVisualizer, self).__init__(
#      51         estimator, ax=ax, fig=fig, **kwargs
#      52     )
#
# YellowbrickTypeError: The supplied model is not a clustering estimator; try a classifier or regression score visualizer instead!

# %%
import sys
# !{sys.executable} -m pip install yellowbrick
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yellowbrick
#   Using cached yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from yellowbrick) (3.10.0)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from yellowbrick) (1.16.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from yellowbrick) (1.8.0)
# Requirement already satisfied: numpy>=1.16.0 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from yellowbrick) (2.2.4)
# Requirement already satisfied: cycler>=0.10.0 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.2)
# Requirement already satisfied: pillow>=8 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Jitendra Dewangan\AppData\Roaming\Python\Python313\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.6.0)
# Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

model = KMeans(random_state=42)

# Added force_model=True to skip type checking
visualizer = KElbowVisualizer(model, k=(1,11), timings=False, force_model=True)

visualizer.fit(df_k)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Prep data
df_k = scaled_df.drop(columns=['Country'], axis=1)

# Calculate inertia
inertia = []
k_range = range(1, 11)

for k in k_range:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    model.fit(df_k)
    inertia.append(model.inertia_)

# Generate the plot
plt.figure(figsize=(8, 4))
plt.plot(k_range, inertia, marker='o', color='blue')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia / Distortion')
plt.title('Elbow Method')
plt.grid(True)
plt.show()

# %%
km = KMeans(n_clusters = 3 )
y_predicted = km.fit_predicted(df_k)
df_k['clusters'] = y_predicted
df_k
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 2
#       1 km = KMeans(n_clusters = 3 )
# ----> 2 y_predicted = km.fit_predicted(df_k)
#       3 df_k['clusters'] = y_predicted
#       4 df_k
#
# AttributeError: 'KMeans' object has no attribute 'fit_predicted'

# %%
km.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 km.cluster_centers_
#
# AttributeError: 'KMeans' object has no attribute 'cluster_centers_'

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
score = silhouette_score(df_k, km.labels_, metrics = 'euclidean')
print(score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[107], line 2
#       1 from sklearn.metrics import silhouette_samples, silhouette_score
# ----> 2 score = silhouette_score(df_k, km.labels_, metrics = 'euclidean')
#       3 print(score)
#
# AttributeError: 'KMeans' object has no attribute 'labels_'
